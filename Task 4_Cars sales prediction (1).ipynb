# %% [markdown]
# # Data Science intership (CodSoft)
#
# ## Topic : Cars Sales Prediction
#
# ![gx-future-of-auto-sales-1_1200-x-675.webp](attachment:gx-future-of-auto-sales-1_1200-x-675.webp)
#
# ### Objective
#
# To create a model that can estimate the overall amount that consumers would spend given the following characteristics:
# customer name, customer email, country, gender, age, annual salary, credit card debt, and net worth

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
data=pd.read_csv('C:/Users/Bilbin T L/Downloads/car_purchasing.csv',encoding='ISO-8859-1')
data
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %%
data.head(5)
# Out:
#      customer name                                    customer e-mail  \
# 0    Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1    Harlan Barnes                                eu.dolor@diam.co.uk
# 2  Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3  Jade Cunningham                            malesuada@dignissim.com
# 4     Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
#
#         country  gender        age  annual Salary  credit card debt  \
# 0      Bulgaria       0  41.851720    62812.09301      11609.380910
# 1        Belize       0  40.870623    66646.89292       9572.957136
# 2       Algeria       1  43.152897    53798.55112      11160.355060
# 3  Cook Islands       1  58.271369    79370.03798      14426.164850
# 4        Brazil       1  57.313749    59729.15130       5358.712177
#
#      net worth  car purchase amount
# 0  238961.2505          35321.45877
# 1  530973.9078          45115.52566
# ...

# %%
df=data.copy()
df
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %%
df.columns
# Out:
# Index(['customer name', 'customer e-mail', 'country', 'gender', 'age',
#        'annual Salary', 'credit card debt', 'net worth',
#        'car purchase amount'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   customer name        500 non-null    object
#  1   customer e-mail      500 non-null    object
#  2   country              500 non-null    object
#  3   gender               500 non-null    int64
#  4   age                  500 non-null    float64
#  5   annual Salary        500 non-null    float64
#  6   credit card debt     500 non-null    float64
#  7   net worth            500 non-null    float64
#  8   car purchase amount  500 non-null    float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 35.3+ KB

# %%
df.describe()
# Out:
#            gender         age  annual Salary  credit card debt  \
# count  500.000000  500.000000     500.000000        500.000000
# mean     0.506000   46.241674   62127.239608       9607.645049
# std      0.500465    7.978862   11703.378228       3489.187973
# min      0.000000   20.000000   20000.000000        100.000000
# 25%      0.000000   40.949969   54391.977195       7397.515792
# 50%      1.000000   46.049901   62915.497035       9655.035568
# 75%      1.000000   51.612263   70117.862005      11798.867487
# max      1.000000   70.000000  100000.000000      20000.000000
#
#             net worth  car purchase amount
# count      500.000000           500.000000
# mean    431475.713625         44209.799218
# std     173536.756340         10773.178744
# min      20000.000000          9000.000000
# 25%     299824.195900         37629.896040
# 50%     426750.120650         43997.783390
# 75%     557324.478725         51254.709517
# max    1000000.000000         80000.000000

# %%
data.isnull().sum()
# Out:
# customer name          0
# customer e-mail        0
# country                0
# gender                 0
# age                    0
# annual Salary          0
# credit card debt       0
# net worth              0
# car purchase amount    0
# dtype: int64

# %%
df=pd.DataFrame(data)
df
# Out:
#        customer name                                    customer e-mail  \
# 0      Martina Avila  cubilia.Curae.Phasellus@quisaccumsanconvallis.edu
# 1      Harlan Barnes                                eu.dolor@diam.co.uk
# 2    Naomi Rodriquez  vulputate.mauris.sagittis@ametconsectetueradip...
# 3    Jade Cunningham                            malesuada@dignissim.com
# 4       Cedric Leach     felis.ullamcorper.viverra@egetmollislectus.net
# ..               ...                                                ...
# 495           Walter                                ligula@Cumsociis.ca
# 496            Vanna                 Cum.sociis.natoque@Sedmolestie.edu
# 497            Pearl                      penatibus.et@massanonante.com
# 498             Nell                  Quisque.varius@arcuVivamussit.net
# 499            Marla                          Camaron.marla@hotmail.com
#
#           country  gender        age  annual Salary  credit card debt  \
# ...

# %% [markdown]
# Drop unwanted column

# %%
c= df.drop(columns=['customer name','customer e-mail'],axis=1)
c
# Out:
#           country  gender        age  annual Salary  credit card debt  \
# 0        Bulgaria       0  41.851720    62812.09301      11609.380910
# 1          Belize       0  40.870623    66646.89292       9572.957136
# 2         Algeria       1  43.152897    53798.55112      11160.355060
# 3    Cook Islands       1  58.271369    79370.03798      14426.164850
# 4          Brazil       1  57.313749    59729.15130       5358.712177
# ..            ...     ...        ...            ...               ...
# 495         Nepal       0  41.462515    71942.40291       6995.902524
# 496      Zimbabwe       1  37.642000    56039.49793      12301.456790
# 497   Philippines       1  53.943497    68888.77805      10611.606860
# 498      Botswana       1  59.160509    49811.99062      14013.034510
# 499        marlal       1  46.731152    61370.67766       9391.341628
#
#        net worth  car purchase amount
# 0    238961.2505          35321.45877
# 1    530973.9078          45115.52566
# ...

# %% [markdown]
# #### Data Visualization

# %%
sns.set_style('darkgrid')
sns.pairplot(data,hue='gender',palette='Greens')

# %%
sns.set_palette('dark')
plt.figure(figsize=(30,10))
sns.histplot(data['country'],alpha=0.4)
plt.title('Data Counts for each Country')
# Out:
# Text(0.5, 1.0, 'Data Counts for each Country')

# %% [markdown]
# Total Paid to a Car vs Net Worth

# %%
sns.set_palette('hls')
sns.lmplot(x='car purchase amount',y='net worth',data=data)

# %% [markdown]
# Amount vs net worth by gender

# %%
plt.figure(figsize=(10,20))
sns.lmplot(x='car purchase amount',y='net worth',data=c,col='gender')

# %%
sns.lmplot(x='age',y='car purchase amount',data=data,hue='gender',markers=['o','v'],palette='tab10')
plt.title('Purchase Amount vs Age hue gender')
# Out:
# Text(0.5, 1.0, 'Purchase Amount vs Age hue gender')

# %% [markdown]
# Salary vs Net Worth

# %%
plt.scatter(data['annual Salary'],data['net worth'])
plt.xlabel('Annual Salary')
plt.ylabel('Net Worth')
plt.title('Salary vs Net Worth')
# Out:
# Text(0.5, 1.0, 'Salary vs Net Worth')

# %% [markdown]
# Splitting the data into train and test

# %%
X =c.drop(columns=['car purchase amount','country'] ,axis=1)
y = c['car purchase amount']

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y.values.reshape(-1, 1))

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (400, 5)
# (400, 1)
# (100, 5)
# (100, 1)

# %% [markdown]
# Linear Regression

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lm.predict(X_test)

# %%
plt.scatter(y_test,y_pred)
plt.xlabel('Real Values')
plt.ylabel('Predicted Values')
plt.title('Real vs Prediction')
# Out:
# Text(0.5, 1.0, 'Real vs Prediction')

# %%
print(f'Mean Absolute Error:{mean_absolute_error(y_test,y_pred)}')
print(f'Mean Squared Error:{mean_squared_error(y_test,y_pred)}')
print(f'R2 Score:{r2_score(y_test,y_pred)}')
# Out:
# Mean Absolute Error:1.7378360519341162e-05
# Mean Squared Error:4.952394765924236e-10
# R2 Score:0.999999979272406
